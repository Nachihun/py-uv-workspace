# %%
def print_3_times():
    print("안녕하세요")
    print("안녕하세요")
    print("안녕하세요")

print_3_times()
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
def print_n_times(value, n):
    for i in range(n):
        print(value)
        print(n)

print_n_times("안녕하세요", 5)
# Out:
# 안녕하세요
# 5
# 안녕하세요
# 5
# 안녕하세요
# 5
# 안녕하세요
# 5
# 안녕하세요
# 5

# %%
def print_n_times(n, *values):
    for i in range(n):
        for value in values:
            print(value)
        print()

print_n_times(3, "안녕하세요", "즐거운", "파이썬 프로그래밍")
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# %%
def print_n_times(value, n=2):
    for i in range(n):
        print(value)

print_n_times("안녕하세요")
# Out:
# 안녕하세요
# 안녕하세요

# %%
def print_n_times(n=2, *values):
    for i in range(n):
        for value in values:
            print(value)
        print()

print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3         for value in values:
#       4             print(value)
#       5         print()
#       6
# ----> 7 print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍")
#
# Cell In[2], line 2, in print_n_times(n, *values)
#       1 def print_n_times(n=2, *values):
# ----> 2     for i in range(n):
#       3         for value in values:
#       4             print(value)
#       5         print()
#
# TypeError: 'str' object cannot be interpreted as an integer

# %%
def print_n_times(*values, n=2):
    for i in range(n):
        for value in values:
            print(value)
        print()

print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍",3)
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
# 3
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
# 3

# %%
def print_n_times(*values, n=2):
    for i in range(n):
        for value in values:
            print(value)
        print()

print_n_times("안녕하세요", "즐거운", "파이썬 프로그래밍",n=3)
# Out:
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍
#
# 안녕하세요
# 즐거운
# 파이썬 프로그래밍

# %%
def test(a, b=10, c=100):
    print(a + b + c)

test(10, 20, 30)

test(a=10, b=100, c=200)

test(c=10, a=100, b=200)

test(10, c=200)
# Out:
# 60
# 310
# 310
# 220

# %%
def return_test():
    print("A 위치입니다.")
    return
    print("B 위치입니다.")

return_test()
# Out:
# A 위치입니다.

# %%
def return_test():
    return 100

value = return_test()
print(value)
# Out:
# 100

# %%
def return_test():
    return

value = return_test()
print(value)
# Out:
# None

# %%
def sum_all(start, end):
    output = 0

    for i in range(start, end + 1):
        output += i

    return output

print("0 to 100 : ", sum_all(0, 100))
print("0 to 1000 : ", sum_all(0, 1000))
print("50 to 100 : ", sum_all(50, 100))
print("500 to 1000 : ", sum_all(500, 1000))
# Out:
# 0 to 100 :  5050
# 0 to 1000 :  500500
# 50 to 100 :  3825
# 500 to 1000 :  375750

# %%
def sum_all(start=0, end=100, step=1):
    output = 0

    for i in range(start, end + 1, step):
        output += i

    return output
print("A. ", sum_all(0, 100, 10))
print("B. ", sum_all(end=100))
print("C. ", sum_all(end=100, step=2))
# Out:
# A.  550
# B.  5050
# C.  2550

# %%
#f(x)=2x+1
def f(x):
    return 2*x+1

print(f(10))
# Out:
# 21

# %%
# f(x) = x^2+2x+1
def f(x):
    return x**2+2*x+1

print(f(10))
# Out:
# 121

# %%
def mul(*values):
    output_mul = 1

    for value in values:
        output_mul = output_mul * value

    return output_mul


print(mul(5, 7, 9, 10))
# Out:
# 3150

# %%
def function(*values, valueA, valueB):
    pass
function(1, 2, 3, 4, 5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[25], line 3
#       1 def function(*values, valueA, valueB):
#       2     pass
# ----> 3 function(1, 2, 3, 4, 5)
#
# TypeError: function() missing 2 required keyword-only arguments: 'valueA' and 'valueB'

# %%
def function(*values, valueA=10, valueB=20):
    pass
function(1, 2, 3, 4, 5)

# %%
def function(valueA, valueB, *values):
    pass
function(1, 2, 3, 4, 5)

# %%
def function(valueA=10, valueB=20, *values):
    pass
function(1, 2, 3, 4, 5)

# %%
def factorial(n):
    output = 1

    for i in range(1, n+1):
        output *= i

    return output

print("1! : ", factorial(1))
print("2! : ", factorial(2))
print("3! : ", factorial(3))
print("4! : ", factorial(4))
print("5! : ", factorial(5))
# Out:
# 1! :  1
# 2! :  2
# 3! :  6
# 4! :  24
# 5! :  120

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n-1)

print("1! : ", factorial(1))
print("2! : ", factorial(2))
print("3! : ", factorial(3))
print("4! : ", factorial(4))
print("5! : ", factorial(5))
# Out:
# 1! :  1
# 2! :  2
# 3! :  6
# 4! :  24
# 5! :  120

# %%
def fibonacci(n):
    if n == 1:
        return 1
    
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
    
print("fibonacci(1) : ", fibonacci(1))
print("fibonacci(2) : ", fibonacci(2))
print("fibonacci(3) : ", fibonacci(3))
print("fibonacci(4) : ", fibonacci(4))
print("fibonacci(5) : ", fibonacci(5))
# Out:
# fibonacci(1) :  1
# fibonacci(2) :  1
# fibonacci(3) :  2
# fibonacci(4) :  3
# fibonacci(5) :  5

# %%
counter = 0

def fibonacci(n):
    print("fibonacci({})를 구합니다.".format(n))
    global counter
    counter += 1

    if n == 1:
        return 1
    
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
    
fibonacci(10)
print("-----")
print("fibonacci(10) 계산할 때 함수를 호출한 횟수는 {}번 입니다.".format(counter))
# Out:
# fibonacci(10)를 구합니다.
# fibonacci(9)를 구합니다.
# fibonacci(8)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(6)를 구합니다.
# fibonacci(5)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(4)를 구합니다.
# fibonacci(3)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(1)를 구합니다.
# fibonacci(2)를 구합니다.
# fibonacci(7)를 구합니다.
# fibonacci(6)를 구합니다.
# ...

# %%
counter = 0

def fibonacci(n):
    print("fibonacci({})를 구합니다.".format(n))
    #global counter
    counter += 1

    if n == 1:
        return 1
    
    if n == 2:
        return 1
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)
    
fibonacci(10)
print("-----")
print("fibonacci(10) 계산할 때 함수를 호출한 횟수는 {}번 입니다.".format(counter))
# Out:
# fibonacci(10)를 구합니다.
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[34], line 16
#      12         return 1
#      13     else:
#      14         return fibonacci(n - 1) + fibonacci(n - 2)
#      15
# ---> 16 fibonacci(10)
#      17 print("-----")
#      18 print("fibonacci(10) 계산할 때 함수를 호출한 횟수는 {}번 입니다.".format(counter))
#
# Cell In[34], line 6, in fibonacci(n)
#       3 def fibonacci(n):
#       4     print("fibonacci({})를 구합니다.".format(n))
#       5     #global counter
# ----> 6     counter += 1
#       7
#       8     if n == 1:
#       9         return 1
#
# UnboundLocalError: cannot access local variable 'counter' where it is not associated with a value

# %%
dictionary = {
    1: 1,
    2: 1
}

def fibonacci(n):
    if n in dictionary:
        return dictionary[n]
    else:
        output = fibonacci(n - 1) + fibonacci(n - 2)
        dictionary[n] = output
        return output
    
print("fibonacci(10) : ", fibonacci(10))
print("fibonacci(20) : ", fibonacci(20))
print("fibonacci(30) : ", fibonacci(30))
print("fibonacci(40) : ", fibonacci(40))
print("fibonacci(50) : ", fibonacci(50))
# Out:
# fibonacci(10) :  55
# fibonacci(20) :  6765
# fibonacci(30) :  832040
# fibonacci(40) :  102334155
# fibonacci(50) :  12586269025

# %%
def flatten(data):
    output = []

    for item in data:
        if type(item) == list:
            output += flatten(item)
        else:
            output.append(item)

    return output

example = [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
print("원본 : ", example)
print("변환 : ", flatten(example))
# Out:
# 원본 :  [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
# 변환 :  [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def flatten(data):
    output = []

    for item in data:
        if type(item) == list:
            output += flatten(item)
        else:
            output.append(item)

    return output

example = [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
print("원본 : ", example)
print("변환 : ", flatten(example))
# Out:
# 원본 :  [[1, 2, 3], [4, [5, 6]], 7, [8, 9]]
# 변환 :  [1, 2, 3, 4, 5, 6, 7, 8, 9]

# %%
def number_input():
    output = input("숫자를 입력하세요. > ")
    return float(output)

def get_circumference(radius):
    return 2 * 3.14 * radius

def get_circle_area(radius):
    return 3.14 * radius * radius

radius = number_input()
print(get_circumference(radius))
print(get_circle_area(radius))
# Out:
# 157.0
# 1962.5

# %%
PI = 3.14

def number_input():
    output = input("숫자를 입력하세요. > ")
    return float(output)

def get_circumference(radius):
    return 2 * PI * radius

def get_circle_area(radius):
    return PI * radius * radius

radius = number_input()
print(get_circumference(radius))
print(get_circle_area(radius))
# Out:
# 144.44
# 1661.06

# %%
def p(content):
    return "<p>{}</p>".format(content)
    
    return "<p class='content-line'>{}</p>". format(content)

print(p("안녕하세요."))
print(p("간단한 HTML태그를 만드는 예입니다."))
# Out:
# <p>안녕하세요.</p>
# <p>간단한 HTML태그를 만드는 예입니다.</p>

# %%
# 교재 chapter05-02, p314, 확인문제  1.

def count_table_patterns(total_people, min_capacity, max_capacity):
    dp = [0] * (total_people + 1)

    dp[0] = 1

    for capacity in range(min_capacity, max_capacity + 1):
        for i in range(capacity, total_people + 1):
            dp[i] += dp[i - capacity]

    return dp[total_people]

total = 100
min_per_table = 2
max_per_table = 10
memo = {}

result = count_table_patterns(total, min_per_table, max_per_table)
print(f"100명을 2~10명씩 나누어 앉히는 패턴의 경우의 수 : {result:,}")
# Out:
# 100명을 2~10명씩 나누어 앉히는 패턴의 경우의 수 : 437,420
