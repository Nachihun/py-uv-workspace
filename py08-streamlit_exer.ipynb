# %%
# %%writefile student.csv
#
# import streamlit as st
#
# header = ['학번', '이름', '전공']
#
# with student_form('my form'):
#     number = st.text_input('학번 : ')
#     name = st.text_input('이름 : ')
#     subjec = st.text_input('전공 : ')
#
#     submit = st.form_submit_button('확인')
#
# if submit:
