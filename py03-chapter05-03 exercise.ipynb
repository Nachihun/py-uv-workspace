# %%
[a, b] = [10, 20]
(c, d) = (30, 40)

print("a : ", a)
print("b : ", b)
print("c : ", c)
print("d : ", d)
# Out:
# a :  10
# b :  20
# c :  30
# d :  40

# %%
tuple_test = 10, 20, 30, 40
print("# 괄호가 없는 튜플의 값과 자료형 출력")
print("tuple_test : ", tuple_test)
print("type(tuple_test) : ", type(tuple_test))
print()

a, b, c = 50, 60, 70
print("# 괄호가 없는 튜플을 활용한 할당")
print("a : ", a)
print("b : ", b)
print("c : ", c)
# Out:
# # 괄호가 없는 튜플의 값과 자료형 출력
# tuple_test :  (10, 20, 30, 40)
# type(tuple_test) :  <class 'tuple'>
#
# # 괄호가 없는 튜플을 활용한 할당
# a :  50
# b :  60
# c :  70

# %%
a, b = 10, 20

print("교환 전 값")
print("a : ", a)
print("b : ", b)
print()

a, b = b, a

print("교환 후 값")
print("a : ", a)
print("b : ", b)
print()
# Out:
# 교환 전 값
# a :  10
# b :  20
#
# 교환 후 값
# a :  20
# b :  10

# %%
def test():
    return(10, 20)

a, b = test()

print("a : ", a)
print("b : ", b)
# Out:
# a :  10
# b :  20

# %%
a, b = 94, 40
print(divmod(a, b))
# Out:
# (2, 14)

# %%
def call_10_times(func):
    for i in range(10):
        func()

def print_hello():
    print("안녕하세요")

call_10_times(print_hello)
# Out:
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요
# 안녕하세요

# %%
def power(item):
    return  item * item

def under_3(item):
    return item < 3

list_input_a = [1, 2, 3, 4, 5]

output_a = map(power, list_input_a)
print("# map() 함수의 실행 결과")
print("map(power, list_inpit_a) : ", output_a)
print("map(power, list_inpit_a) : ", list(output_a))
print()

output_b = filter(under_3, list_input_a)
print("# filter() 함수의 실행 결과")
print("filter(under_3, list_inpup_a) : ", output_b)
print("filter(under_3, list_input_a) : ", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_inpit_a) :  <map object at 0x0000027965E5A0E0>
# map(power, list_inpit_a) :  [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_inpup_a) :  <filter object at 0x0000027965E599F0>
# filter(under_3, list_input_a) :  [1, 2]

# %%
# def power(item):
#    return  item * item

power = lambda x : x * x

#def under_3(item):
#    return item < 3

under_3 = lambda x : x < 3

list_input_a = [1, 2, 3, 4, 5]

output_a = map(power, list_input_a)
print("# map() 함수의 실행 결과")
print("map(power, list_inpit_a) : ", output_a)
print("map(power, list_inpit_a) : ", list(output_a))
print()

output_b = filter(under_3, list_input_a)
print("# filter() 함수의 실행 결과")
print("filter(under_3, list_inpup_a) : ", output_b)
print("filter(under_3, list_input_a) : ", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_inpit_a) :  <map object at 0x0000027965E2B820>
# map(power, list_inpit_a) :  [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_inpup_a) :  <filter object at 0x0000027965E58760>
# filter(under_3, list_input_a) :  [1, 2]

# %%
# def power(item):
#    return  item * item

# power = lambda x : x * x

#def under_3(item):
#    return item < 3

# under_3 = lambda x : x < 3

list_input_a = [1, 2, 3, 4, 5]

output_a = map(lambda x : x * x, list_input_a)
print("# map() 함수의 실행 결과")
print("map(power, list_inpit_a) : ", output_a)
print("map(power, list_inpit_a) : ", list(output_a))
print()

output_b = filter(lambda x : x < 3, list_input_a)
print("# filter() 함수의 실행 결과")
print("filter(under_3, list_inpup_a) : ", output_b)
print("filter(under_3, list_input_a) : ", list(output_b))
# Out:
# # map() 함수의 실행 결과
# map(power, list_inpit_a) :  <map object at 0x0000027965E5A7D0>
# map(power, list_inpit_a) :  [1, 4, 9, 16, 25]
#
# # filter() 함수의 실행 결과
# filter(under_3, list_inpup_a) :  <filter object at 0x0000027965E2BB80>
# filter(under_3, list_input_a) :  [1, 2]

# %%
file = open("basic.txt", "w")

file.write("Hello Python Programming....!!!")

file. close()

# %%
with open("basic1.txt", "w") as file:
    file.write("Hello Python Programming....!!!!!!@@@@")

# %%
with open("basic.txt", "r") as file:
    contents = file.read()

print(contents)
# Out:
# Hello Python Programming....!!!

# %%
import random

hanguls = list("가나다라마바사아자차카타파하")

with open("info.txt", "w") as file:
    for i in range(1000):
        name = random.choice(hanguls) + random.choice(hanguls)
        weight = random.randrange(40, 100)
        height = random.randrange(140, 200)

        file.write("{}, {}, {}\n".format(name, weight, height))

# %%
with open("info.txt", "r") as file:
    for line in file:
        (name, weight, height) = line.strip().split(", ")

        if (not name) or (not weight) or (not height):
            continue

        bmi = int(weight) / ((int(height) / 100) ** 2)
        result = ""
        if 25 <= bmi:
            result = "과체중"
        elif 18.5 <=  bmi:
            result = "정상 체중"
        else:
            result = "저체중"

        print('\n'.join([
            "이름 : {}",
            "몸무게 : {}",
            "키 : {}",
            "BMI : {}",
            "결과: {}"
        ]).format(name,  weight, height, bmi, result))
        print()
# Out:
# 이름 : 마자
# 몸무게 : 59
# 키 : 148
# BMI : 26.93571950328707
# 결과: 과체중
#
# 이름 : 하다
# 몸무게 : 62
# 키 : 186
# BMI : 17.921146953405014
# 결과: 저체중
#
# 이름 : 카라
# 몸무게 : 65
# 키 : 157
# BMI : 26.370238143535232
# 결과: 과체중
#
# 이름 : 라아
# 몸무게 : 67
# 키 : 142
# BMI : 33.227534219400916
# 결과: 과체중
#
# 이름 : 파가
# 몸무게 : 90
# 키 : 180
# BMI : 27.777777777777775
# 결과: 과체중
#
# 이름 : 파마
# 몸무게 : 67
# 키 : 140
# BMI : 34.18367346938776
# 결과: 과체중
#
# 이름 : 라가
# 몸무게 : 97
# 키 : 196
# BMI : 25.249895876718035
# 결과: 과체중
#
# 이름 : 다마
# 몸무게 : 53
# 키 : 193
# BMI : 14.228569894493813
# 결과: 저체중
#
# 이름 : 타파
# 몸무게 : 57
# 키 : 148
# BMI : 26.02264426588751
# 결과: 과체중
#
# 이름 : 마사
# 몸무게 : 42
# 키 : 178
# BMI : 13.255902032571644
# 결과: 저체중
#
# 이름 : 아사
# 몸무게 : 65
# 키 : 184
# BMI : 19.198960302457465
# 결과: 정상 체중
#
# 이름 : 사가
# 몸무게 : 91
# 키 : 163
# BMI : 34.25044224472129
# 결과: 과체중
#
# 이름 : 바카
# 몸무게 : 44
# 키 : 174
# BMI : 14.532963403355794
# 결과: 저체중
#
# 이름 : 자바
# 몸무게 : 61
# 키 : 146
# BMI : 28.61700131356728
# 결과: 과체중
#
# 이름 : 파다
# 몸무게 : 62
# ...

# %%
with open("test.txt", "w")  as file:
    file.writelines(["안녕하세요.",\
                     "줄바꿈이 될까요?",\
                    "안될까요??",\
                    "띄어쓰기라도 하지 않을까요???"])
    
    file.writelines([True, 273, "문자열"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[32], line 7
#       3                      "줄바꿈이 될까요?",\
#       4                     "안될까요??",\
#       5                     "띄어쓰기라도 하지 않을까요???"])
#       6
# ----> 7     file.writelines([True, 273, "문자열"])
#
# TypeError: write() argument must be str, not bool

# %%
def test():
    print("함수가 호출되었습니다.")
    yield "test"

print("A 지점 통과")
test()

print("B 지점 통과")
test()
print(test())
# Out:
# A 지점 통과
# B 지점 통과
# <generator object test at 0x0000027965BD8DC0>

# %%
def test():
    print("A 지점 통과")
    yield 1
    print("B 지점 통과")
    yield 2
    print("C 지점 통과")

output = test()

print("D 지점 통과")
a = next(output)
print(a)
print("E 지점 통과")
b = next(output)
print(b)
print("F 지점 통과")
c = next(output)
print(c)
next(output)
# Out:
# D 지점 통과
# A 지점 통과
# 1
# E 지점 통과
# B 지점 통과
# 2
# F 지점 통과
# C 지점 통과
# ---------------------------------------------------------------------------
# StopIteration                             Traceback (most recent call last)
# Cell In[35], line 17
#      13 print("E 지점 통과")
#      14 b = next(output)
#      15 print(b)
#      16 print("F 지점 통과")
# ---> 17 c = next(output)
#      18 print(c)
#      19 next(output)
#
# StopIteration:

# %%
a = [52, 273, 32, 103, 57]
print(min(a))
print(max(a))
# Out:
# 32
# 273

# %%
books = [{
    "제목" : "혼자 공부하는 파이썬",
    "가격" : 18000
},{
    "제목" : "혼자 공부하는 머신러닝 + 딥러닝",
    "가격" : 26000
},{
    "제목" : "혼자 공부하는 자바스크립트",
    "가격" : 24000
}]

def  price(book):
    return book["가격"]

print("# 가장 저렴한책")
print(min(books,  key=price))
print()

print("# 가장 비싼 책")
print(max(books, key=price))
# Out:
# # 가장 저렴한책
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
#
# # 가장 비싼 책
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %%
books = [{
    "제목" : "혼자 공부하는 파이썬",
    "가격" : 18000
},{
    "제목" : "혼자 공부하는 머신러닝 + 딥러닝",
    "가격" : 26000
},{
    "제목" : "혼자 공부하는 자바스크립트",
    "가격" : 24000
}]

#def  price(book):
#    return book["가격"]

print("# 가장 저렴한책")
print(min(books,  key=lambda book : book["가격"]))
print()

print("# 가장 비싼 책")
print(max(books, key=lambda book : book["가격"]))
# Out:
# # 가장 저렴한책
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
#
# # 가장 비싼 책
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %%
a = [52, 273, 103, 32, 57, 272]
a.sort()
print(a)
a.sort(reverse=True)
print(a)
# Out:
# [32, 52, 57, 103, 272, 273]
# [273, 272, 103, 57, 52, 32]

# %%
books = [{
    "제목" : "혼자 공부하는 파이썬",
    "가격" : 18000
},{
    "제목" : "혼자 공부하는 머신러닝 + 딥러닝",
    "가격" : 26000
},{
    "제목" : "혼자 공부하는 자바스크립트",
    "가격" : 24000
}]

print("# 가격 오름차순 정렬")
books.sort(key=lambda book : book["가격"])
for book in books:
    print(book)
# Out:
# # 가격 오름차순 정렬
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
# {'제목': '혼자 공부하는 자바스크립트', '가격': 24000}
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}

# %%
books = [{
    "제목" : "혼자 공부하는 파이썬",
    "가격" : 18000
},{
    "제목" : "혼자 공부하는 머신러닝 + 딥러닝",
    "가격" : 26000
},{
    "제목" : "혼자 공부하는 자바스크립트",
    "가격" : 24000
}]

print("# 가격 내림차순 정렬")
books.sort(key=lambda book : book["가격"], reverse=True)
for book in books:
    print(book)
# Out:
# # 가격 내림차순 정렬
# {'제목': '혼자 공부하는 머신러닝 + 딥러닝', '가격': 26000}
# {'제목': '혼자 공부하는 자바스크립트', '가격': 24000}
# {'제목': '혼자 공부하는 파이썬', '가격': 18000}
